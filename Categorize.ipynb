# %%
import pandas as pd
import re

# %%
df = pd.read_csv('hdh18-20_proteins_with_units.csv')

# %%
df
# Out:
#       INVOICE_DATE            LOC          VENDOR PO_NUMBER INVOICE_NUMBER  \
# 0         02/08/19  Cafe Ventanas  Hamilton Meats        LA         270380
# 1         02/08/19     64 Degrees  Hamilton Meats        LM         270379
# 2         02/08/19     64 Degrees  Hamilton Meats        LM         270378
# 3         02/08/19     64 Degrees  Hamilton Meats        LM         270379
# 4         02/08/19     64 Degrees  Hamilton Meats        LM         270378
# ...            ...            ...             ...       ...            ...
# 27507     05/28/20   Canyon Vista           SYSCO        pr      236389733
# 27508     06/01/20  Cafe Ventanas           SYSCO        pr      236392064
# 27509     06/17/20     64 Degrees           SYSCO        pr      236404573
# 27510     06/19/20     64 Degrees           SYSCO        pr      236405974
# 27511     06/29/20     64 Degrees           SYSCO        pr      236413529
#
# ...

# %% [markdown]
# # CLEANING
#  25061/25061 rows
# ### STEPS
# 1. seperate by category
# 2. find unique ITEMs
# 3. create function to handle all ITEMS and granularize
# 4. create a new column TYPE to store
# 5. combine all dataframes (1 per category)

# %% [markdown]
# # BEEF
# - 3592 rows
# - 3717

# %%
beef = df[df['CATEGORY'] == 'Beef']
beef['ITEM'] = beef['ITEM'].str.lower()
beef
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       INVOICE_DATE            LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 386       05/01/18       Foodworx  SYSCO       DLJ      136557849
# 393       05/02/18          Pines  SYSCO    tkk-pr      136558972
# 403       05/02/18       Club Med  SYSCO    EPD-pr      136559130
# 428       05/03/18   Canyon Vista  SYSCO      G-CW      136560171
# 430       05/03/18     64 Degrees  SYSCO    pcl-CW      136560044
# ...            ...            ...    ...       ...            ...
# 27356     02/10/20  Cafe Ventanas  SYSCO        pr      236300335
# 27391     02/19/20  Cafe Ventanas  SYSCO        pr      236311465
# ...

# %%
beef['ITEM'].unique()
# Out:
# array(['beef roast btm rnd sli .67', 'beef meatball italian 1oz. 1315',
#        'hot dog franks 6x1 6" 1219', 'gyro meat sliced 1153',
#        'beef patty 8:1 1029', 'pepperoni all beef 4522',
#        'halal ground beef 2117', 'halal beef patty 5:1 0764',
#        'meat gyro beef/lamb raw 1152', 'beef patty ground 4 to1 1032',
#        'halal beef patty 4:1 0770', 'beef patty ground 4 :1 1032',
#        'beef ground blk 81/19 fine', 'kosher ground beef 80/20 raw 2',
#        'picada carne asada 0170', 'beef tenderloin 189a 0142',
#        'pastrami beef navel 0305', 'beef round ins top bid 007',
#        'beef stew 1x1 90% lean 135', 'beef ground 80/20 0053',
#        'supplement beef 0842', 'mongolian beef pre cut 10',
#        'corned beef brisket 0759', 'beef tri tip 0758',
#        'beef ribeye roll 112a bid 8', 'steak new york 1469',
#        'steak ribeye util cto 1045', 'beef picada diced 0169',
#        'beef brisket 120a 8410', 'beef flank steak 193 0062',
# ...

# %%
def beef_categorize(x):
    if 'halal' in x:
        if 'ground' in x:
            return 'Halal Ground Beef'
        elif 'patty' in x:
            return 'Halal Beef Patty'
        elif 'tri tip' in x:
            return 'Halal Beef Tri Tip'
        elif 'ball' in x:
            return 'Halal Beef Ball'
        elif 'stir fry' in x:
            return 'Halal Beef Stir Fry'
        elif 'carne asada' in x:
            return 'Halal Carne Asada'
        else:
            return 'Halal Beef Other'
    elif 'kosher' in x:
        if 'ground' in x:
            return 'Kosher Ground Beef'
        elif 'brisket' in x:
            return 'Kosher Beef Brisket'
        elif 'pastrami' in x:
            return 'Kosher Beef Pastrami'
        else:
            return 'Kosher Beef Other'
    elif 'stew' in x:
        return 'Beef Stew'
    elif 'carne asada' in x or 'picada' in x:
        return 'Picada Carne Asada'
    elif 'gyro' in x:
        return 'Beef Gyro'
    elif 'roast' in x:
        return 'Beef Roast'
    elif 'patty' in x:
        return 'Beef Patty'
    elif 'ground' in x:
        return 'Beef Ground'
    elif 'mongolian' in x:
        return 'Beef Mongolian'
    elif 'round' in x:
        return 'Beef Round'
    elif 'pastrami' in x:
        return 'Beef Pastrami'
    elif 'hot dog' in x:
        return 'Beef Hot Dog'
    elif 'meatball' in x:
        return 'Beef Meatball'
    elif 'supplement' in x:
        return 'Beef Supplement'
    elif 'tri tip' in x:
        return 'Beef Tri Tip'
    elif 'supplement' in x:
        return 'Beef Supplement'
    elif 'sirloin' in x:
        return 'Beef Sirloin'
    elif 'tenderloin' in x:
        return 'Beef Tenderloin'
    elif 'new york' in x:
        return 'New York Steak'
    elif 'ribeye' in x:
        return 'Beef Ribeye'
    elif 'country fried' in x:
        return 'Beef Country Fried'
    elif 'flank' in x:
        return 'Beef Flank'
    elif 'brisket' in x:
        return 'Beef Brisket'
    elif 'pepperoni' in x:
        return 'Beef Pepperoni'
    elif 'chorizo' in x:
        return 'Beef Chorizo'
    elif 'cutlet' in x:
        return 'Beef Cutlet'
    elif 'kabob' in x:
        return 'Beef Kabob'
    else:
        return 'Beef Other'

# %%
beef['TYPE'] = beef['ITEM'].apply(beef_categorize)
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#beef

# %%
beef['TYPE'].value_counts()
# Out:
# Beef Patty              929
# Picada Carne Asada      634
# Beef Roast              495
# Beef Hot Dog            281
# Beef Pastrami           216
# Beef Pepperoni          161
# New York Steak          125
# Beef Ground             109
# Beef Tri Tip            107
# Beef Round              102
# Beef Supplement          99
# Halal Beef Patty         69
# Beef Tenderloin          65
# Beef Mongolian           61
# Beef Meatball            54
# Beef Gyro                51
# Halal Beef Tri Tip       25
# Beef Country Fried       21
# Beef Ribeye              18
# Halal Ground Beef        16
# Beef Stew                12
# Halal Carne Asada        12
# Beef Kabob               10
# Halal Beef Ball          10
# Beef Brisket              9
# Beef Chorizo              9
# Beef Sirloin              6
# Kosher Ground Beef        4
# Beef Flank                2
# Beef Cutlet               2
# Kosher Beef Brisket       1
# Kosher Beef Pastrami      1
# Halal Beef Stir Fry       1
# ...

# %% [markdown]
# # CHICKEN
# - 4734 rows
# - 4808

# %%
chkn = df[df['CATEGORY'] == 'Chicken']
chkn['ITEM'] = chkn['ITEM'].str.lower()
chkn
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       INVOICE_DATE            LOC          VENDOR PO_NUMBER INVOICE_NUMBER  \
# 0         02/08/19  Cafe Ventanas  Hamilton Meats        LA         270380
# 1         02/08/19     64 Degrees  Hamilton Meats        LM         270379
# 2         02/08/19     64 Degrees  Hamilton Meats        LM         270378
# 3         02/08/19     64 Degrees  Hamilton Meats        LM         270379
# 4         02/08/19     64 Degrees  Hamilton Meats        LM         270378
# ...            ...            ...             ...       ...            ...
# 25679     09/21/18  Cafe Ventanas           SYSCO        BR      136719204
# ...

# %%
#chkn['ITEM'].unique()

# %%
def chkn_categorizer(x):
    if 'kosher' in x:
        if 'wogs' in x:
            return 'Kosher Chicken Wing'
        else:
            return 'Kosher Chicken Other'
    elif 'halal' in x:
        if 'breast' in x:
            return 'Halal Chicken Breast'
        elif 'ground' in x:
            return 'Halal Ground Chicken'
        elif 'thigh' in x:
            return 'Halal Chicken Thigh'
        elif 'wing' in x:
            return 'Halal Chicken Wing'
        else:
            return 'Halal Chicken Other'
    elif 'wog' in x or 'wing' in x:
        return 'Chicken Wing'
    elif 'breast' in x:
        return 'Chicken Breast'
    elif 'ground' in x:
        return 'Ground Chicken'
    elif 'thigh' in x:
        return 'Chicken Thigh'
    elif 'leg' in x:
        return 'Chicken Leg'
    elif 'tenderloin' in x:
        return 'Chicken Tenderloin'
    elif 'orange' in x:
        return 'Orange Chicken'
    elif 'tender' in x:
        return 'Chicken Tenders'
    elif 'pulled' in x:
        return 'Pulled Chicken'
    elif 'supplement' in x:
        return 'Chicken Supplement'
    elif 'kabob' in x:
        return 'Chicken Kabob'
    elif 'diced' in x:
        return 'Chicken Diced'
    elif 'do not' in x:
        return 'Chicken DO NOT'
    else:
        return 'Chicken Other'

# %%
chkn['TYPE'] = chkn['ITEM'].apply(chkn_categorizer)
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#chkn 
#chkn[chkn['TYPE'] == 'Chicken Other']['ITEM'].value_counts()

# %%
chkn['TYPE'].value_counts()
# Out:
# Chicken Breast          1171
# Chicken Thigh           1058
# Chicken Tenders          994
# Chicken Wing             547
# Chicken Supplement       446
# Orange Chicken           362
# Chicken Leg               73
# Chicken DO NOT            60
# Kosher Chicken Wing       32
# Chicken Diced             29
# Chicken Tenderloin        10
# Chicken Kabob              8
# Halal Ground Chicken       5
# Halal Chicken Breast       4
# Halal Chicken Wing         4
# Halal Chicken Thigh        4
# Pulled Chicken             1
# Name: TYPE, dtype: int64

# %% [markdown]
# # PORK
# - 4912 rows
# - 5314

# %%
pork = df[df['CATEGORY'] == 'Pork']
pork['ITEM'] = pork['ITEM'].str.lower()
pork
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       INVOICE_DATE         LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 383       05/01/18       Pines  SYSCO    tkk-CW      136557822
# 384       05/01/18       Pines  SYSCO    tkk-CW      136557822
# 387       05/01/18    Foodworx  SYSCO       DLJ      136557849
# 391       05/01/18  64 Degrees  SYSCO    pcl-CW      136557818
# 392       05/01/18  64 Degrees  SYSCO    pcl-CW      136557818
# ...            ...         ...    ...       ...            ...
# 26865     09/18/19    Club Med  SYSCO        pr      236134564
# 26870     09/18/19  64 Degrees  SYSCO        pr      236134561
# ...

# %%
#pork['ITEM'].unique()

# %%
def pork_categorizer(x):
    if 'bacon' in x:
        return 'Pork Bacon'
    elif 'ham' in x:
        return 'Pork Ham'
    elif 'sausage' in x or 'link' in x:
        return 'Pork Sausage'
    elif 'pepperoni' in x:
        return 'Pork Pepperoni'
    elif 'salami' in x:
        return 'Pork Salami'
    elif 'ground' in x:
        return 'Ground Pork'
    elif 'ribs' in x:
        return 'Pork Ribs'
    elif 'chop' in x:
        return 'Pork Chop'
    elif 'round' in x:
        return 'Pork Round'
    elif 'butt' in x:
        return 'Pork Butt'
    elif 'belly' in x:
        return 'Pork Belly'
    elif 'carnitas' in x:
        return 'Pork Carnitas'
    elif 'loin' in x:
        return 'Pork Loin'
    elif 'supplement' in x:
        return 'Pork Supplement'
    elif 'stew' in x:
        return 'Pork Stew'
    elif 'pancetta' in x:
        return 'Pork Pancetta'
    else:
        return 'Pork Other'

# %%
pork['TYPE'] = pork['ITEM'].apply(pork_categorizer)
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#pork

# %%
pork['TYPE'].value_counts()
# Out:
# Pork Sausage       1690
# Pork Bacon         1491
# Pork Ham            626
# Pork Carnitas       399
# Pork Butt           344
# Pork Ribs           199
# Pork Belly          141
# Pork Loin           120
# Pork Salami         105
# Pork Pancetta        55
# Ground Pork          45
# Pork Supplement      34
# Pork Stew            33
# Pork Pepperoni       24
# Pork Chop             8
# Name: TYPE, dtype: int64

# %% [markdown]
# # EGGS
# - 4189 rows
# - 4328

# %%
eggs = df[df['CATEGORY'] == 'Eggs']
eggs['ITEM'] = eggs['ITEM'].str.lower()
eggs
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       INVOICE_DATE            LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 381       05/01/18          Pines  SYSCO    tkk-CW      136557822
# 390       05/01/18     64 Degrees  SYSCO    pcl-CW      136557818
# 395       05/02/18          Pines  SYSCO    tkk-pr      136558972
# 396       05/02/18          Pines  SYSCO    tkk-pr      136558972
# 404       05/02/18       Club Med  SYSCO    EPD-pr      136559130
# ...            ...            ...    ...       ...            ...
# 25352     02/18/20  Cafe Ventanas  SYSCO        pr      236310185
# 25353     02/27/20      OceanView  SYSCO        pr      236320658
# ...

# %%
#eggs['ITEM'].unique()

# %%
def egg_categorizer(x):
    if 'liquid' in x:
        if 'white' in x:
            return 'Egg Whites Liquid'
        else:
            return 'Egg Liquid'
    elif 'shell' in x:
        return 'Egg Shell Lg'
    elif 'hardboil' in x:
        return 'Egg Hardboiled'
    elif 'supplement' in x or 'supplememt' in x:
        return 'Egg Supplement'
    else:
        return 'Egg Other'

# %%
eggs['TYPE'] = eggs['ITEM'].apply(egg_categorizer)
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#eggs

# %%
eggs['TYPE'].value_counts()
# Out:
# Egg Liquid           1778
# Egg Shell Lg         1325
# Egg Hardboiled        833
# Egg Whites Liquid     376
# Egg Supplement         16
# Name: TYPE, dtype: int64

# %% [markdown]
# # LEGUMES
# - 3418 rows
# - 4968

# %%
legumes = df[df['CATEGORY'] == 'Legumes']
legumes['ITEM'] = legumes['ITEM'].str.lower()
legumes
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       INVOICE_DATE            LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 382       05/01/18          Pines  SYSCO    tkk-CW      136557822
# 397       05/02/18          Pines  SYSCO    tkk-pr      136558972
# 409       05/02/18  Cafe Ventanas  SYSCO     im-pr      136559124
# 412       05/02/18     The Bistro  SYSCO     ws-pr      136559126
# 418       05/03/18          Pines  SYSCO    tkk-pr      136560048
# ...            ...            ...    ...       ...            ...
# 27507     05/28/20   Canyon Vista  SYSCO        pr      236389733
# 27508     06/01/20  Cafe Ventanas  SYSCO        pr      236392064
# ...

# %%
#legumes['ITEM'].unique()

# %%
def legume_categorizer(x):
    if 'tofu' in x:
        return 'Tofu'
    elif 'lentil' in x:
        return 'Lentil'
    elif 'bean' in x:
        if 'soy' in x:
            return 'Soybean'
        elif 'garbanzo' in x:
            return 'Garbanzo Beans'
        elif 'green' in x:
            return 'Green Beans'
        elif 'peas' in x:
            return 'Peas'
        elif 'refried' in x:
            return 'Refried Beans'
        elif 'pinto' in x:
            return 'Pinto Beans'
        elif 'kidney' in x:
            return 'Kidney Beans'
        else:
            return 'Bean Other'
    elif 'peanut' in x:
        if 'butter' in x or 'skippy' in x:
            return 'Peanut Butter'
        elif 'sauce' in x:
            return 'Peanut Sauce'
        else:
            return 'Peanut Other'
    elif 'edamame' in x:
        return 'Edamame'
    else:
        return 'Legumes Other'

# %%
legumes['TYPE'] = legumes['ITEM'].apply(legume_categorizer)
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#legumes

# %%
#legumes[legumes['TYPE'] == 'Peanut Butter']['ITEM'].value_counts()

# %%
legumes['TYPE'].value_counts()
# Out:
# Tofu              1588
# Refried Beans      754
# Bean Other         699
# Garbanzo Beans     587
# Green Beans        318
# Kidney Beans       289
# Pinto Beans        271
# Soybean            214
# Edamame             88
# Lentil              80
# Peanut Butter       73
# Peanut Sauce         5
# Legumes Other        2
# Name: TYPE, dtype: int64

# %% [markdown]
# # TURKEY
# - 2501 rows
# - 2506

# %%
tky = df[df['CATEGORY'] == 'Turkey']
tky['ITEM'] = tky['ITEM'].str.lower()
tky
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       INVOICE_DATE            LOC          VENDOR PO_NUMBER INVOICE_NUMBER  \
# 310       06/24/19  Cafe Ventanas  SP (Do Not Use        CW          56755
# 338       07/22/19  Cafe Ventanas  SP (Do Not Use        BR          58399
# 371       08/06/19  Cafe Ventanas  SP (Do Not Use        LM          59417
# 374       08/12/19  Cafe Ventanas  SP (Do Not Use        LM          59638
# 378       10/14/19  Cafe Ventanas  SP (Do Not Use        BR          63610
# ...            ...            ...             ...       ...            ...
# 25223     03/30/20          Pines           SYSCO        CW      236351280
# ...

# %%
#tky['ITEM'].unique()

# %%
def tky_categorizer(x):
    if 'kosher' in x:
        if 'ground' in x:
            return 'Kosher Ground Turkey'
        elif 'whole' in x:
            return 'Kosher Whole Turkey'
        else:
            'Kosher Turkey Other'
    elif 'ground' in x:
        return 'Ground Turkey'
    elif 'breast' in x:
        return 'Turkey Breast'
    elif 'meatball' in x:
        return 'Turkey Meatball'
    elif 'corn dog' in x:
        return 'Turkey Corn Dog'
    elif 'patty' in x:
        return 'Turkey Patty'
    elif 'sausage' in x:
        return 'Turkey Sausage'
    elif 'toms' in x:
        return 'Turkey Toms'
    elif 'supplement' in x:
        return 'Turkey Supplement'
    else:
        return 'Turkey Other'

# %%
tky['TYPE'] = tky['ITEM'].apply(tky_categorizer)
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#tky

# %%
tky['TYPE'].value_counts()
# Out:
# Turkey Breast           1260
# Turkey Patty             689
# Turkey Corn Dog          318
# Turkey Sausage           148
# Ground Turkey             51
# Turkey Supplement         15
# Turkey Meatball           12
# Kosher Whole Turkey        6
# Turkey Toms                5
# Kosher Ground Turkey       2
# Name: TYPE, dtype: int64

# %% [markdown]
# # PROCESSED VEGETARIAN PROTEINS
# - 1715 rows
# - 1871

# %%
veg = df[df['CATEGORY'] == 'Processed Vegetarian Protein']
veg['ITEM'] = veg['ITEM'].str.lower()
veg
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       INVOICE_DATE            LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 1503      09/05/18  Cafe Ventanas  SYSCO        pr      136701256
# 1523      09/10/18          Pines  SYSCO        CW      136706055
# 1560      09/13/18          Pines  SYSCO        pr      136710051
# 1573      09/14/18  Cafe Ventanas  SYSCO        pr      136711947
# 1608      09/21/18      OceanView  SYSCO        BR      136719201
# ...            ...            ...    ...       ...            ...
# 27344     02/06/20     64 Degrees  SYSCO        CW      236296994
# 27361     02/10/20     64 Degrees  SYSCO        pr      236300331
# ...

# %%
#veg['ITEM'].unique()

# %%
def veg_categorizer(x):
    if 'patty' in x:
        if 'black bean' in x:
            return 'Black Bean Patty'
        elif 'vegan' in x:
            return 'Vegan Patty'
        elif 'vegetable' in x:
            return 'Spicy Vegetarian Patty'
    elif 'chix' in x and 'breast' in x:
        return 'Chix Breast (Veg)'
    elif 'mozz' in x and 'vegn' in x:
        return 'Vegan Mozz. Cheese'
    elif 'soy chorizo' in x:
        return 'Soy Chorizo'
    elif 'soy fishless' in x:
        return 'Soy Fishless Filet'
    elif 'sausage' in x and 'apple sage' in x:
        return 'Apple Sage Sausage'
    elif 'vg nat forest young jack' in x:
        return 'Vg Young Jack'
    elif 'just egg' in x:
        return 'Vegan Eggs'
    else:
        return 'Processed Vegetarian Protein Other'

# %%
veg['TYPE'] = veg['ITEM'].apply(veg_categorizer)
# Out:
# /Users/vinay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#veg

# %%
#veg[veg['TYPE'] == 'Processed Vegetarian Protein Other']['ITEM'].value_counts()

# %%
veg['TYPE'].value_counts()
# Out:
# Spicy Vegetarian Patty    483
# Black Bean Patty          422
# Soy Chorizo               214
# Vegan Patty               179
# Chix Breast (Veg)         148
# Soy Fishless Filet        142
# Vg Young Jack             130
# Vegan Mozz. Cheese        125
# Apple Sage Sausage         21
# Vegan Eggs                  5
# Name: TYPE, dtype: int64

# %% [markdown]
# # COMBO
# - 27,316 rows (out of 27,316)
# - 27512

# %%
combo = pd.concat([beef, chkn, pork, legumes, eggs, tky, veg], axis=0, ignore_index=True)

# %%
combo
# Out:
#       INVOICE_DATE           LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 0         05/01/18      Foodworx  SYSCO       DLJ      136557849
# 1         05/02/18         Pines  SYSCO    tkk-pr      136558972
# 2         05/02/18      Club Med  SYSCO    EPD-pr      136559130
# 3         05/03/18  Canyon Vista  SYSCO      G-CW      136560171
# 4         05/03/18    64 Degrees  SYSCO    pcl-CW      136560044
# ...            ...           ...    ...       ...            ...
# 27507     02/06/20    64 Degrees  SYSCO        CW      236296994
# 27508     02/10/20    64 Degrees  SYSCO        pr      236300331
# 27509     02/19/20    64 Degrees  SYSCO        pr      236311463
# 27510     02/20/20    64 Degrees  SYSCO        CW      236312645
# 27511     02/25/20    64 Degrees  SYSCO        pr      236318195
#
#                                     ITEM  QUANTITY    UNIT   COST  \
# 0             beef roast btm rnd sli .67       3.0  4/2.5#  56.11
# ...

# %%
combo['TYPE'].value_counts()
# Out:
# Egg Liquid              1778
# Pork Sausage            1690
# Tofu                    1588
# Pork Bacon              1491
# Egg Shell Lg            1325
#                         ...
# Beef Cutlet                2
# Halal Beef Stir Fry        1
# Pulled Chicken             1
# Kosher Beef Pastrami       1
# Kosher Beef Brisket        1
# Name: TYPE, Length: 103, dtype: int64

# %%
combo.to_csv('hdh18-20_units_and_types.csv', index=False)

# %%
combo
# Out:
#       INVOICE_DATE           LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 0         05/01/18      Foodworx  SYSCO       DLJ      136557849
# 1         05/02/18         Pines  SYSCO    tkk-pr      136558972
# 2         05/02/18      Club Med  SYSCO    EPD-pr      136559130
# 3         05/03/18  Canyon Vista  SYSCO      G-CW      136560171
# 4         05/03/18    64 Degrees  SYSCO    pcl-CW      136560044
# ...            ...           ...    ...       ...            ...
# 27507     02/06/20    64 Degrees  SYSCO        CW      236296994
# 27508     02/10/20    64 Degrees  SYSCO        pr      236300331
# 27509     02/19/20    64 Degrees  SYSCO        pr      236311463
# 27510     02/20/20    64 Degrees  SYSCO        CW      236312645
# 27511     02/25/20    64 Degrees  SYSCO        pr      236318195
#
#                                     ITEM  QUANTITY    UNIT   COST  \
# 0             beef roast btm rnd sli .67       3.0  4/2.5#  56.11
# ...

# %%
combo_melt = combo.melt(id_vars=['INVOICE_DATE', 'LOC', 'VENDOR', 'PO_NUMBER', 'INVOICE_NUMBER', 'ITEM', 'QUANTITY', 'UNIT', 'COST', 'EXTENDED_COST', 'VENDOR_NO', 'CATEGORY', 'CM_OR_INV', 'TYPE'], value_vars=['Num_Pounds', 'Num_Count', 'Num_Cases'])

# %%
combo_melt = combo_melt[combo_melt['value'].notna()].reset_index().drop(['index'], axis=1)
combo_melt
# Out:
#       INVOICE_DATE            LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 0         05/01/18       Foodworx  SYSCO       DLJ      136557849
# 1         05/02/18          Pines  SYSCO    tkk-pr      136558972
# 2         05/02/18       Club Med  SYSCO    EPD-pr      136559130
# 3         05/03/18   Canyon Vista  SYSCO      G-CW      136560171
# 4         05/03/18     64 Degrees  SYSCO    pcl-CW      136560044
# ...            ...            ...    ...       ...            ...
# 27507     03/18/20  Goody's Place  SYSCO        CW      236344583
# 27508     03/18/20  Cafe Ventanas  SYSCO        CW      236344579
# 27509     03/18/20  Cafe Ventanas  SYSCO        CW      236344579
# 27510     03/25/20     64 Degrees  SYSCO        pr      236349095
# 27511     03/30/20          Pines  SYSCO        CW      236351280
#
#                                   ITEM  QUANTITY    UNIT   COST  \
# 0           beef roast btm rnd sli .67       3.0  4/2.5#  56.11
# ...

# %%
combo_melt.to_csv('hdh18-20_valuecolumn.csv', index=False)

# %%
combo_melt['Total_Value'] = combo_melt['QUANTITY'] * combo_melt['value']
combo_melt
# Out:
#       INVOICE_DATE            LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 0         05/01/18       Foodworx  SYSCO       DLJ      136557849
# 1         05/02/18          Pines  SYSCO    tkk-pr      136558972
# 2         05/02/18       Club Med  SYSCO    EPD-pr      136559130
# 3         05/03/18   Canyon Vista  SYSCO      G-CW      136560171
# 4         05/03/18     64 Degrees  SYSCO    pcl-CW      136560044
# ...            ...            ...    ...       ...            ...
# 27507     03/18/20  Goody's Place  SYSCO        CW      236344583
# 27508     03/18/20  Cafe Ventanas  SYSCO        CW      236344579
# 27509     03/18/20  Cafe Ventanas  SYSCO        CW      236344579
# 27510     03/25/20     64 Degrees  SYSCO        pr      236349095
# 27511     03/30/20          Pines  SYSCO        CW      236351280
#
#                                   ITEM  QUANTITY    UNIT   COST  \
# 0           beef roast btm rnd sli .67       3.0  4/2.5#  56.11
# ...

# %%
combo_melt.to_csv('hdh18-20_totals.csv', index=False)

# %%
SP = combo[(combo['VENDOR'] == 'SP (Do Not Use') | (combo['VENDOR'] == 'Seaport Meat Co')] # ['EXTENDED_COST'].sum()

# %%
SP[SP['INVOICE_DATE'].str.endswith('19')]['EXTENDED_COST'].sum()
# Out:
# 349061.5

# %%
nomayjune = pd.read_csv('hdh18-20_valuecolumn_NOMAYJUNE.csv')
nomayjune
# Out:
#       INVOICE_DATE            LOC VENDOR PO_NUMBER INVOICE_NUMBER  \
# 0         05/01/18       Foodworx  SYSCO       DLJ      136557849
# 1         05/02/18          Pines  SYSCO    tkk-pr      136558972
# 2         05/02/18       Club Med  SYSCO    EPD-pr      136559130
# 3         05/03/18   Canyon Vista  SYSCO      G-CW      136560171
# 4         05/03/18     64 Degrees  SYSCO    pcl-CW      136560044
# ...            ...            ...    ...       ...            ...
# 27311     03/18/20  Goody's Place  SYSCO        CW      236344583
# 27312     03/18/20  Cafe Ventanas  SYSCO        CW      236344579
# 27313     03/18/20  Cafe Ventanas  SYSCO        CW      236344579
# 27314     03/25/20     64 Degrees  SYSCO        pr      236349095
# 27315     03/30/20          Pines  SYSCO        CW      236351280
#
#                                   ITEM  QUANTITY    UNIT   COST  \
# 0           beef roast btm rnd sli .67       3.0  4/2.5#  56.11
# ...

# %%
nomayjune[nomayjune['ITEM'] == 'chicken breast 5oz 2195'] #['COST'].value_counts()
# Out:
#      INVOICE_DATE            LOC          VENDOR PO_NUMBER INVOICE_NUMBER  \
# 3329     02/08/19  Cafe Ventanas  Hamilton Meats        LA         270380
# 3330     02/08/19     64 Degrees  Hamilton Meats        LM         270379
# 3331     02/08/19     64 Degrees  Hamilton Meats        LM         270378
# 3334     02/11/19  Cafe Ventanas  Hamilton Meats        LM         270669
# 3339     02/12/19     64 Degrees  Hamilton Meats       KSZ         270667
# ...           ...            ...             ...       ...            ...
# 7237     10/22/18  Cafe Ventanas           SYSCO        CW      136754784
# 7280     11/06/18     64 Degrees           SYSCO        pr      136774146
# 7411     01/24/19      OceanView           SYSCO        pr      136859874
# 7698     11/07/19  Cafe Ventanas           SYSCO        jm      236194839
# 7705     11/08/19  Cafe Ventanas           SYSCO        JM      236196060
#
#                          ITEM  QUANTITY   UNIT  COST  EXTENDED_COST  \
# ...

# %%
nomayjune[nomayjune['TYPE'] == 'Chicken Breast']['value'].value_counts()
# Out:
# 1.0     452
# 20.0    435
# 40.0    271
# Name: value, dtype: int64

# %%
nomayjune[nomayjune['TYPE'] == 'Egg Liquid']['value'].sum()
# Out:
# 70840.0

# %%
nomayjune[nomayjune['TYPE'] == 'Egg Liquid']['QUANTITY'].sum()
# Out:
# 4647.0

# %%
70840 * 4647
# Out:
# 329193480
